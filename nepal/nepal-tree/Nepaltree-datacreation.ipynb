# %%
import json
import random as random

# %%
with open("NepalG.json", 'r') as f5:
    Nepal = json.load(f5)

# %%
Data = []
i = 1; j = 1; k = 1; l = 1
Data.append({"id" : "Nepal", "value":str(i)})

for key,value in Nepal.items():
    PV = key
    dists = value
    
    Data.append({"id":"Nepal"+"."+PV,\
                 "value":str(i) + "." + str(j)})
    
    j =j+1
    
    for key,value in dists.items():
        
        district = key
        MP = value
        
        Data.append({"id":"Nepal"+"."+PV+"."+district,\
                     "value":str(i) + "." + str(j) + "." +str(k)})
        k = k+1
        
        
        for key,value in MP.items():
            mcp = key
            l = l+1
            
            Data.append({"id":"Nepal"+"."+PV+"."+district+"."+ mcp,\
                         "value":str(i) + "." + str(j) + "." +str(k) + "."+str(k)})

# %%
import pandas as pd
DF = pd.DataFrame(Data)
DF = DF.set_index("id")

# %%
DF.head(200)
# Out:
#                                             value
# id
# Nepal                                           1
# Nepal.PN1                                     1.1
# Nepal.PN1.Bhojpur                           1.2.1
# Nepal.PN1.Bhojpur.Bhojpur MCP             1.2.2.2
# Nepal.PN1.Bhojpur.Shadanada MCP           1.2.2.2
# Nepal.PN1.Bhojpur.Tyamke Maiyum RM        1.2.2.2
# Nepal.PN1.Bhojpur.Ram Prasad Rai RM       1.2.2.2
# Nepal.PN1.Bhojpur.Arun RM                 1.2.2.2
# Nepal.PN1.Bhojpur.PauwaDungama RM         1.2.2.2
# Nepal.PN1.Bhojpur.Salpasilichho RM        1.2.2.2
# Nepal.PN1.Bhojpur.Aamchok RM              1.2.2.2
# Nepal.PN1.Bhojpur.HatuwaGadhi RM          1.2.2.2
# Nepal.PN1.Dhankuta                          1.2.2
# Nepal.PN1.Dhankuta.Pakhribas MCP          1.2.3.3
# Nepal.PN1.Dhankuta.Dhankuta MCP           1.2.3.3
# Nepal.PN1.Dhankuta.Mahalaxmi MCP          1.2.3.3
# Nepal.PN1.Dhankuta.SanguriGadhi RM        1.2.3.3
# Nepal.PN1.Dhankuta.Khalsa Chhintaag RM    1.2.3.3
# Nepal.PN1.Dhankuta.Chhathat Jorpati RM    1.2.3.3
# Nepal.PN1.Dhankuta.Chaubise RM            1.2.3.3
# Nepal.PN1.Ilam                              1.2.3
# Nepal.PN1.Ilam.Ilam MCP                   1.2.4.4
# Nepal.PN1.Ilam.Deumai MCP                 1.2.4.4
# Nepal.PN1.Ilam.Mai MCP                    1.2.4.4
# Nepal.PN1.Ilam.Suryodaya MCP              1.2.4.4
# Nepal.PN1.Ilam.Phakaphokthum RM           1.2.4.4
# Nepal.PN1.Ilam.Chulachuli RM              1.2.4.4
# Nepal.PN1.Ilam.Mai Jogmai RM              1.2.4.4
# Nepal.PN1.Ilam.Mangsebung RM              1.2.4.4
# Nepal.PN1.Ilam.Rong RM                    1.2.4.4
# ...                                           ...
# Nepal.PN2.Parsa.Subarnapur RM           1.3.17.17
# Nepal.PN2.Parsa.Jagarnathapur RM        1.3.17.17
# Nepal.PN2.Parsa.Dhobini RM              1.3.17.17
# Nepal.PN2.Parsa.Chhipahar Mai RM        1.3.17.17
# Nepal.PN2.Parsa.Pakaha Mainpur RM       1.3.17.17
# Nepal.PN2.Parsa.Bindabasini RM          1.3.17.17
# Nepal.PN2.Parsa.Bahudar Mai RM          1.3.17.17
# Nepal.PN2.Parsa.Belawa RM               1.3.17.17
# Nepal.PN2.Parsa.Parsa Gadhi RM          1.3.17.17
# Nepal.PN2.Parsa.Sakhuwa Prasouni RM     1.3.17.17
# Nepal.PN2.Parsa.Paterwa Sugauli RM      1.3.17.17
# Nepal.PN2.Bara                             1.3.17
# Nepal.PN2.Bara.Kalaiya S-MCP            1.3.18.18
# Nepal.PN2.Bara.Jitpur Simara S-MCP      1.3.18.18
# Nepal.PN2.Bara.Kolhabi MCP              1.3.18.18
# Nepal.PN2.Bara.Nijgadh MCP              1.3.18.18
# Nepal.PN2.Bara.Maha Gahdimai MCP        1.3.18.18
# Nepal.PN2.Bara.Simraun Gadh MCP         1.3.18.18
# Nepal.PN2.Bara.Adarsha Kotwal RM        1.3.18.18
# Nepal.PN2.Bara.Karaiya Mai RM           1.3.18.18
# Nepal.PN2.Bara.Devtaal RM               1.3.18.18
# Nepal.PN2.Bara.PachaRouta RM            1.3.18.18
# Nepal.PN2.Bara.Parawanipur RM           1.3.18.18
# Nepal.PN2.Bara.Prasouni RM              1.3.18.18
# Nepal.PN2.Bara.Pheta RM                 1.3.18.18
# Nepal.PN2.Bara.Bara Gadhi               1.3.18.18
# Nepal.PN2.Bara.Subarna RM               1.3.18.18
# Nepal.PN2.Siraha                           1.3.18
# Nepal.PN2.Siraha.Lahan MCP              1.3.19.19
# Nepal.PN2.Siraha.DhangadhiMai MCP       1.3.19.19
#
# [200 rows x 1 columns]

# %%
DF.to_csv("nepaltree.csv")
# The file had "." on Some of the field names in PN7. Fixed that manually in csv file.
# Working file name named Nepal.csv.
#Run Nepal.html to get the tree diagram.
